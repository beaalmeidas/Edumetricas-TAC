# %%
# %pip install pandas

# %%
import pandas as pd

# %%
df_enem = pd.read_csv("../data/RESULTADOS_2024.csv", encoding='latin-1', sep=';')

df_enem.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4332944 entries, 0 to 4332943
# Data columns (total 42 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   NU_SEQUENCIAL           int64
#  1   NU_ANO                  int64
#  2   CO_ESCOLA               float64
#  3   CO_MUNICIPIO_ESC        float64
#  4   NO_MUNICIPIO_ESC        str
#  5   CO_UF_ESC               float64
#  6   SG_UF_ESC               str
#  7   TP_DEPENDENCIA_ADM_ESC  float64
#  8   TP_LOCALIZACAO_ESC      float64
#  9   TP_SIT_FUNC_ESC         float64
#  10  CO_MUNICIPIO_PROVA      int64
#  11  NO_MUNICIPIO_PROVA      str
#  12  CO_UF_PROVA             int64
#  13  SG_UF_PROVA             str
#  14  TP_PRESENCA_CN          int64
#  15  TP_PRESENCA_CH          int64
#  16  TP_PRESENCA_LC          int64
#  17  TP_PRESENCA_MT          int64
#  18  CO_PROVA_CN             float64
#  19  CO_PROVA_CH             float64
#  20  CO_PROVA_LC             float64
# ...

# %%
colunas = ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']

df_enem = pd.read_csv("../data/RESULTADOS_2024.csv", 
                        encoding='latin-1', sep=';',
                        usecols=colunas)

df_amostra = df_enem.sample(n=20000, random_state=42)
df_amostra.to_csv("../data/enem_2024_amostra.csv", index=False)
