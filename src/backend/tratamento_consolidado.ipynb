# %%
# %pip install pandas numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../data/internal/output/consolidado.csv")

df["situacao"] = (
    df["situacao"]
    .str.strip()
    .str.replace(r"Reprovado.*", "Reprovado", regex=True)
    .str.replace(r"Aprovado.*", "Aprovado", regex=True)
)

df.to_csv("../../data/internal/output/consolidado.csv", index=False)
